# %%
#Use python 13.12

# %%
import matplotlib.pyplot as plt
import numpy as np

species = ("CsPbBr3 \n (Cs104-A)", "CsPbBr3 \n (Cs106)", "MAPbBr3 \n (SC67-B)")
configuration = {
    'No source': (2.08, 1.22, 0.81),
    'Am241': (5.15, 0.00, 0.00),
    'Cs137': (11.06, 0.00, 0.00),
    'Sr90': (0.00, 5.84, 2.28)
}

x = np.arange(len(species))  # the label locations
width = 0.20  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(constrained_layout=True)

for attribute, measurement in configuration.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    ax.bar_label(rects, padding=4)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Rate (Hz)')
ax.set_title('Event rates w/ and w/o source exposure')
ax.set_xticks(x + 1.5*width, species)
ax.legend(loc='upper left', ncols=4)
ax.set_ylim(0, 20)
``
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

species = ('No source', 'Am241', 'Cs137')
configuration = {
    'No source': (2.08),
    'Am241': (5.15),
    'Cs137': (11.06),
    }

x = np.arange(len(species))  # the label locations
width = 0.20  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(constrained_layout=True)

for attribute, measurement in configuration.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    ax.bar_label(rects, padding=4)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Rate (Hz)')
ax.set_title('Event rates w/ and w/o source exposure')
ax.set_xticks(x + width, species)
ax.legend(loc='upper left', ncols=4)
ax.set_ylim(0, 20)

plt.show()

# %%
species = ['No source', 'Am241', 'Cs137']
rate = [2.08, 5.15, 11.06]

fig, ax = plt.subplots()
bar_container = ax.bar(species, rate)
ax.set(ylabel='Rate [Hz]', title='Event rates w/ and w/o source exposure', ylim=(0, 15))
ax.bar_label(bar_container, fmt=lambda x: f'{x :.1f} Hz')

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

species = ['No source', 'Am241', 'Cs137']
rate = [2.08, 5.15, 11.06]

#fruits = ['apple', 'blueberry', 'cherry', 'orange']
#counts = [40, 100, 30, 55]
bar_labels = ['No source', 'Am241', 'Cs137']
bar_colors = ['tab:red', 'tab:blue', 'tab:orange']

ax.bar(species, rate, label=bar_labels, color=bar_colors)



#ax.set_ylabel('Rate [Hz]')
ax.set(ylabel='Rate [Hz]', ylim=(0, 15))

ax.set_title('Event rates w/ and w/o source exposure')
for i, v in enumerate(rate):
    ax.text(i, v + 0.5, f'{v:.2f} Hz', ha='center', va='bottom')
#ax.legend(title='')

plt.show()

# %%
import matplotlib.pyplot as plt

# Data
species = ['No source', 'Am241', 'Cs137']
rate = [2.08, 5.15, 11.06]
bar_colors = ['tab:red', 'tab:blue', 'tab:orange']

# Plot
fig, ax = plt.subplots(figsize=(6, 4))
bars = ax.bar(species, rate, color=bar_colors)

# Labels inside bars
for bar, value in zip(bars, rate):
    ax.text(
        bar.get_x() + bar.get_width() / 2,
        bar.get_height() / 2,
        f'{value:.2f} Hz',
        ha='center',
        va='center',
        color='white',
        fontsize=12,
        fontweight='bold'
    )

# Axis formatting
ax.set_ylabel('Rate [Hz]', fontsize=12)
ax.set_title('Event Rates With and Without Source Exposure', fontsize=14)
ax.set_xticks([])  # Remove x-axis labels

# Optional grid
ax.yaxis.grid(True, linestyle='--', alpha=0.7)

# Clean look
ax.spines[['top', 'right']].set_visible(False)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
#species = ['No source', '$^{241}$Am \n ($\gamma$@ 60keV)', '$^{137}$Cs \n ($\gamma$@ 662keV)']

#xlabels = ['No source', 'Am241', 'Cs137']
species = [
    'No source',
    r'$^{241}$Am' + '\n' + r'$\gamma$ @ 60 keV',
    r'$^{137}$Cs' + '\n' + r'$\gamma$ @ 662 keV'
]
rate = [2.08, 5.15, 11.06]
bar_colors = ['tab:red', 'tab:blue', 'tab:orange']

# Plot
fig, ax = plt.subplots(figsize=(20, 10))
bars = ax.bar(species, rate, color=bar_colors)

# Labels inside bars (species name and rate)
for bar, value, label in zip(bars, rate, species):
    x = bar.get_x() + bar.get_width() / 2
    y = bar.get_height()
    
    # Species name (top of bar center)
    ax.text(x, y * 0.65, label, ha='center', va='center', color='white', fontsize=16, fontweight='bold')
    
    # Rate (bottom of bar center)
    ax.text(x, y * 0.35, f'{value:.2f} Hz', ha='center', va='center', color='white', fontsize=16)

    # Add crystal label with box
ax.text(
    0.25, 0.80, "CsPbBr₃",  # text and position in axes coords
    transform=ax.transAxes,
    fontsize=24,
    verticalalignment='top',
    horizontalalignment='right',
    bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.3')
)

# Axis formatting
ax.set_ylabel('Rate [Hz]', fontsize=12)
ax.set_title('Event Rates With and Without Source Exposure', fontsize=14)
#ax.set_xticks([])  # Remove x-axis labels
#ax.bar(species, rate, label=bar_labels, color=bar_colors)
# Optional grid
ax.yaxis.grid(True, linestyle='--', alpha=0.7)

# Clean look
ax.spines[['top', 'right']].set_visible(False)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

#fig, ax = plt.subplots()
fig, ax = plt.subplots(figsize=(15,7))

species = ['No source', 'Am241', 'Cs137']
rate = [2.08, 5.15, 11.06]

#fruits = ['apple', 'blueberry', 'cherry' ]
types = [
    '',
     r'$\gamma$ @ 60 keV' + '\n' + r'363.5 MBq',
     r'$\gamma$ @ 662 keV' + '\n' + r'3.1 MBq'
]

#counts = [40, 100, 30, 55]
bar_labels = ['No source', 'Am241', 'Cs137']
bar_colors = ['tab:red', 'tab:blue', 'tab:orange']

bars = ax.bar(species, rate, color=bar_colors)

# Labels inside bars (species name and rate)
for bar, value, label in zip(bars, rate, types):
    x = bar.get_x() + bar.get_width() / 2
    y = bar.get_height()
    
    # Species name (top of bar center)
    ax.text(x, y * 0.65, label, ha='center', va='center', color='white', fontsize=16, fontweight='bold')
    

#ax.bar(species, rate, label=bar_labels, color=bar_colors)



#ax.set_ylabel('Rate [Hz]')
ax.set(ylabel='Rate [Hz]', ylim=(0, 15))

ax.set_title('Event rates w/ and w/o source exposure')
for i, v in enumerate(rate):
    ax.text(i, v + 0.5, f'{v:.2f} Hz', ha='center', va='bottom')
#ax.legend(title='')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

species = ("1 mV", "3 mV", "5 mV", "7 mV", "10 mV", "12 mV", "15 mV", "17 mV", "20 mV")
configuration = {
    'No source': (909.09, 833.33, 909.09, 909.09, 322.58, 102.04, 13.79, 2.79, 0.00),
    #'Am241': (5.15, 0.00, 0.00),
    'Cs137': (0.00, 0.00, 0.00, 0.00, 454.55, 156.25, 54.95, 37.45, 25.00)
    #'Sr90': (0.00, 5.84, 2.28)
}


x = np.arange(len(species))  # the label locations
width = 0.20  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(constrained_layout=True)

for attribute, measurement in configuration.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    ax.bar_label(rects, padding=4)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Rate (Hz)')
ax.set_title('Event rates w/ and w/o source exposure')
ax.set_xticks(x + 0.5*width, species)
ax.set_yscale('log')
ax.legend(loc='upper right', ncols=1)
ax.set_ylim(1, 1500)
ax.yaxis.grid(True, linestyle='--', alpha=0.7, color='gray',)
#ax.spines[['top', 'right']].set_visible(False)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

species = ( "7 mV", "10 mV", "12 mV", "15 mV", "17 mV", "20 mV")
configuration = {
    'Cs137': (14.08, 3.29, 1.67, 1.37, 0.00, 0.00),
    #'Am241': (5.15, 0.00, 0.00),
    'Co60': (11.1, 5.3, 0.00, 5.64, 3.42, 1.58)
    #'Sr90': (0.00, 5.84, 2.28)
}


x = np.arange(len(species))  # the label locations
width = 0.20  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(constrained_layout=True)

for attribute, measurement in configuration.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    ax.bar_label(rects, padding=4)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Rate (Hz)')
ax.set_title('Event rates w/ Cs137 and Co60 source exposure (MAPbBr3 - SC67-B)')
ax.set_xticks(x + 0.5*width, species)
#ax.set_yscale('log')
ax.legend(loc='upper right', ncols=1)
ax.set_ylim(1, 20)
ax.yaxis.grid(True, linestyle='--', alpha=0.7, color='gray',)
#ax.spines[['top', 'right']].set_visible(False)

plt.show()
